# %% [markdown]
# <h1 align="center"> Airbnb price category prediction </h1>
# <h2 align="center"> competition #4 </h2>
#
#
# ---
#
#
#
# ---
#
#
# # **Name:**  Sandra Girgis
# # **ID:** 20399121

# %% [markdown]
# # ⭐ Problem Statement
#
# ☘️ Airbnb is a popular online platform that allows travelers to book accommodations from a wide range of options, including apartments, houses, and rooms. The platform offers hosts the flexibility to set their own prices for their listings, which can vary based on a variety of factors such as location, property type, and amenities.
#
# ☘️ The goal of this project is to develop a machine learning model that can accurately predict the price category of an Airbnb listing based on its features. The price categories in this project are defined as low, medium, and high, and the model is expected to predict the correct category for a given listing.
#
# ☘️ This project is of interest to both Airbnb hosts and travelers, as it can help hosts to set competitive prices for their listings and can help travelers to find affordable accommodations that meet their needs.
#
# 👉🏻 So, **The problem statement** boils down to the Airbnb price category prediction project is to develop a machine learning model that can predict the price category of Airbnb listings based on various features such as location, property type, number of bedrooms, and amenities.

# %% [markdown]
# ### ⭐ The input of the Airbnb price category prediction project:
# 👉🏻 Dataset containing various features of Airbnb listings, such as location, property type, number of bedrooms, and amenities. These features are used to train a machine learning model to predict the price category of a given listing.
#
# ### ⭐ The output of the project:
# 👉🏻 The predicted price category of an Airbnb listing, which is classified as either low, medium, or high. This output is generated by applying the trained machine learning model to a new set of listings that were not used in the training phase.

# %% [markdown]
# ### ⭐ The required data mining functions for the Airbnb price category prediction project:
#
# 🔥 Text inputs with at least one GRU/LSTM layer: This requires an NLP function to process textual data, such as the textual descriptions of Airbnb listings. The GRU/LSTM layer is a type of RNN that can learn long-term dependencies in sequential data such as text. The NLP function would preprocess the textual data, such as tokenizing and embedding the words, before feeding them into the GRU/LSTM layer to predict the price category of the listing.
#
# 🔥 Text inputs with at least one BiDirectional layer: This also requires an NLP function to process textual data, but with a BiDirectional layer. A BiDirectional layer processes the input sequence in both forward and backward directions, allowing the model to capture dependencies in both directions. This can improve the accuracy of the model in predicting the price category of Airbnb listings based on textual descriptions.
#
# 🔥 Image inputs with at least one Conv2d layer: This requires a computer vision function to process image data, such as the images of Airbnb listings. The Conv2d layer is a type of CNN layer that can learn spatial patterns in images. The computer vision function would preprocess the image data, such as resizing and normalizing the images, before feeding them into the Conv2d layer to predict the price category of the listing.
#
# 🔥 Image inputs with at least one Dropout layer: This also requires a computer vision function to process image data, but with a Dropout layer. The Dropout layer randomly drops out some of the neurons during training, which can prevent overfitting and improve the generalization of the model.
#
# 🔥 Multi-modality learning with at least one text+image model: This requires a function that can combine the NLP and computer vision functions into a single model that can process both textual and image data. One way to achieve this is through a multi-modal fusion approach, which combines the features learned from both the textual and image inputs before making a prediction about the price category of the listing.
#
# 🔥 Multi-objective learning with at least one multi-objective model: This requires a function that can predict both the price and type of Airbnb listings, which are two different target variables. One way to achieve this is through a multi-task learning approach, where the model is trained to predict both targets simultaneously. Alternatively, an ensemble of models could be used, where each model predicts a different target variable.

# %% [markdown]
# ### ⭐ **The challenges in this project:**
# 👉🏻 The Airbnb price category prediction project involves several challenges that need to be addressed to build an accurate and effective machine learning model. Some of these challenges include:
#
# ☘️ Data quality: The quality of the data is critical for building an accurate model. The dataset may have missing values, outliers, or errors that need to be handled appropriately during preprocessing.
#
# ☘️ Feature engineering: Feature engineering is the process of selecting and transforming the most relevant features to improve the performance of the model. Selecting the right features can be challenging, especially when dealing with a large number of variables.
#
# ☘️ Model selection: There are several machine learning models to choose from, and selecting the right one can be challenging. The model must be able to handle the complexity of the data and make accurate predictions.
#
# ☘️ Overfitting and underfitting: Overfitting occurs when the model is too complex and fits the training data too well, leading to poor generalization on new data. Underfitting occurs when the model is too simple and cannot capture the complexity of the data. Balancing the model's complexity is crucial to avoid overfitting or underfitting.
#
# ☘️ Multi-modality and multi-objective learning: Combining multiple data modalities (text and image) and predicting multiple targets (price and type) can be challenging. The model must be able to handle the complexity of the data and capture the dependencies between different modalities and targets.
#
# ☘️ Interpretability: Interpreting the model's predictions and understanding the features that drive them is important, especially in real-world applications. Black-box models such as neural networks can be difficult to interpret, and interpretability techniques may need to be employed to gain insight into the model's decision-making process.

# %% [markdown]
# ⭐ **The impact of this project**  can be significant for both Airbnb and its users, by improving pricing strategies, enhancing the user experience, and increasing market efficiency..
#
# </br>
# </br>
#
# <p align = "center"> So let's work on the data that we have to see what this problem leads us to do and what is the accurate solution....😃</p>

# %% [markdown]
# # Part I) Data Preparation

# %% [markdown]
# ## I.I) Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

import sklearn
# !pip install googletrans
# !pip install googletrans==3.1.0a0 --user
from googletrans import Translator


from sklearn.model_selection import train_test_split, cross_val_score, KFold

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, precision_score,recall_score, f1_score,precision_recall_curve
sns.set()
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.svm import SVC
from time import time
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA

from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
# from xgboost.ensemble import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.model_selection import PredefinedSplit

import re
import pickle
import nltk 

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neural_network import MLPClassifier
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
     

from tqdm.notebook import tqdm
from PIL import Image
import os
from ast import literal_eval

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from pprint import pprint


from __future__ import absolute_import, division, print_function, unicode_literals
import collections
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D, GRU, LSTM, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## I.II) Loading Data

# %%
train_data = pd.read_csv("train_xy.csv")
test_data = pd.read_csv("test_x.csv")

# %% [markdown]
# ## I.III) Describing Data

# %%
train_data.head()
# Out:
#                                              summary            image  \
# 0  Spacious, sunny and cozy modern apartment in t...  img_train/0.jpg
# 1  Located in one of the most vibrant and accessi...  img_train/1.jpg
# 2  Logement coquet et douillet à 10 minutes du ce...  img_train/2.jpg
# 3  Beautiful and spacious (1076 sc ft, / 100 mc) ...  img_train/3.jpg
# 4  Très grand appartement ''rustique'' et très ag...  img_train/4.jpg
#
#         type  price
# 0  Apartment      1
# 1  Apartment      0
# 2  Apartment      1
# 3  Apartment      1
# 4  Apartment      0

# %%
train_data.describe()
# Out:
#              price
# count  7627.000000
# mean      0.442769
# std       0.611946
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       2.000000

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7627 entries, 0 to 7626
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   summary  7326 non-null   object
#  1   image    7627 non-null   object
#  2   type     7627 non-null   object
#  3   price    7627 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 238.5+ KB

# %%
train_data.dtypes
# Out:
# summary    object
# image      object
# type       object
# price       int64
# dtype: object

# %%
train_data.nunique()
# Out:
# summary    6844
# image      7627
# type         24
# price         3
# dtype: int64

# %%
train_data['price'].value_counts()
# Out:
# 0    4737
# 1    2403
# 2     487
# Name: price, dtype: int64

# %%
test_data.head()
# Out:
#    id                                            summary           image
# 0   0  Charming warm house is ready to host you here ...  img_test/0.jpg
# 1   1  La chambre est spacieuse et lumineuse, dans un...  img_test/1.jpg
# 2   2  Grande chambre confortable située au sous-sol ...  img_test/2.jpg
# 3   3  Près d’un Métro, ligne orange. 10 minutes à pi...  img_test/3.jpg
# 4   4  Very bright appartment and very cosy. 2 separa...  img_test/4.jpg

# %%
test_data.describe()
# Out:
#                 id
# count  7360.000000
# mean   3816.978533
# std    2202.164810
# min       0.000000
# 25%    1912.750000
# 50%    3815.500000
# 75%    5722.250000
# max    7630.000000

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7360 entries, 0 to 7359
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       7360 non-null   int64
#  1   summary  7360 non-null   object
#  2   image    7360 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 172.6+ KB

# %%
test_data.dtypes
# Out:
# id          int64
# summary    object
# image      object
# dtype: object

# %%
test_data.nunique()
# Out:
# id         7360
# summary    6903
# image      7360
# dtype: int64

# %% [markdown]
# ## II.III) Visualize Images and some plots

# %%
Image.open(
            'img_train/0.jpg'
        ).convert('LA')
# Out:
# <PIL.Image.Image image mode=LA size=720x480>

# %%
train_data['type'].value_counts().sort_values(ascending = False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
train_data['price'].value_counts().sort_values(ascending = False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Part II)Data Preprocessing

# %% [markdown]
# ## II.I) Text Preprocessing

# %% [markdown]
# ### II.I.I) Handeling Unconsistence datatypes

# %%
train_data['type'] = train_data['type'].astype('category').cat.codes
train_data['price'] = train_data['price'].astype('category').cat.codes

len_type = len(train_data.type.unique())
len_price = len(train_data.price.unique())

# %% [markdown]
# ### II.I.II) Drop Null values

# %%
# train_data.isna().sum()

# %%
train_data = train_data.dropna()

# %% [markdown]
# ### II.I.III) Translate Text

# %%
# Translate Text
translator = Translator()
train_data['summary'] = [translator.translate(x, dest='en').text for x in train_data['summary']]

# %% [markdown]
# ### II.I.V) Remove Duplicate Values

# %%
train_data = train_data.drop_duplicates(keep=False)

# %% [markdown]
# ## II.II) Image Preprocessing

# %%
# preprocess image data

def load_image(file):
    try:
        image = Image.open(
            file
        ).convert('LA').resize((64, 64))
        arr = np.array(image)
    except:
        arr = np.zeros((64, 64, 2))
    return arr


# loading images:
x_train_image = np.array([load_image(i) for i in tqdm(train_data.image)])
x_test_image = np.array([load_image(i) for i in tqdm(test_data.image)])


# get type 
y_train_type = train_data['type']

# get price
y_train_price = train_data['price']
# Out:
# ...
#   0%|          | 0/7360 [00:00<?, ?it/s]

# %%
# check image loading
import matplotlib.pyplot as plt
plt.imshow(x_train_image[0, :, :, 0])

# %% [markdown]
# ## II.III) Text Preprocessing

# %%
# change summary type: 
# loading summary: (force convert some of the non-string cell to string)
train_data['summary'] = train_data['summary'].astype('str')
test_data['summary'] = test_data['summary'].astype('str')

# %%
# loading overview: (force convert some of the non-string cell to string)
x_train_text = train_data.summary.astype('str')
# loading overview: (force convert some of the non-string cell to string)
x_test_text = _preprocess(test_data.summary.astype('str'))

# %%
vocab_size = 50000
max_len = 100


# build vocabulary from training set
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(train_data.summary)
tokenizer.fit_on_texts(test_data.summary)


def _preprocess(list_of_text):
    return pad_sequences(
        mm_tokenizer.texts_to_sequences(list_of_text),
        maxlen=max_len,
        padding='post',
    )
    

# padding is done inside: 
x_train_text_id = _preprocess(train_data['summary'])
x_test_text_id = _preprocess(test_data['summary'])

print(x_train_text_id.shape)
print(x_test_text_id.shape)
# Out:
# (7326, 100)
# (7360, 100)

# %%
# Tring to convert IDs to the normal text
pprint(tokenizer.sequences_to_texts(x_train_text_id[:5]))
# Out:
# ['spacious sunny and cozy modern apartment in the heart of montreal this 3 '
#  'bedroom heating located in the very hec plateau mont royal neighborhood in '
#  'the saq of pouvant highways rentals only street close to all amenities '
#  'restaurants coffee house bars clubs shopping minimum subway stations '
#  'experience montreal like a complete local abbott be in the heart of the '
#  'museums grand chaussée galleries setting saint laurent si musée ten and so '
#  'villeray more',
#  'located in one of the most vibrant and top machines of downtown montreal '
#  'this one bedroom condo will not only sunnybrooke you but snowdon you with '
#  'one of the most made skiing it is walking distance of the hec stove '
#  'catherine street the bell center the old port lachine canal coquet metro and '
#  'villeray villeray more',
#  'logement cross et bachelor à 10 minutes du centre ville de montréal épicerie '
#  'entièrement yet restaurants et promenade en étudiants à proximité deux '
# ...

# %% [markdown]
# # Part III) Building The Model

# %% [markdown]
# # III.I) Multi-Modality Multi-Task Model

# %% [markdown]
# #### ▶ Using Multi-Modailty Teqniques because we have two kind of data (text and Images) so we want to compine the result of the two models in one model so we use Multi-modality Technique

# %% [markdown]
# ⭐ In **Trial #1** we will use **Multi-modality** that use Two kinds of data(Text and Images) with **Multi-Task** to predict **both Price and Type** of the houses in our dataset.
#
# ⭐ In this Trial we will use simple **average of embedding** to train tesxt data and will use simple **conv2D**, **Maxpool2D** and **flatten** Layers to train the images, after that we will concat the result of two models and then use **two Dense layers** with **Softmax** activation function **one for each Task**.
#
#
# ⭐ Then we will compile the model with **Adam** optimizer and using the **SparseCategoricalAccuracy** loss function and **SparseCategoricalAccuracy** metric to measure the performance of the model.

# %% [markdown]
# ## III.I.I) Trial #1 (Using Multi-Modality & Multi-Task)

# %%
# Importing Libraries
from __future__ import absolute_import, division, print_function, unicode_literals
import collections
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
from tensorflow.keras.optimizers import Adam


# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding.
embedded = keras.layers.Embedding(tokenizer.num_words, 100)(in_text)
averaged = tf.reduce_mean(embedded, axis=1)


# image part 
# simple conv2d. 
cov = Conv2D(32, (16, 16))(in_image)
pl = MaxPool2D((16, 16))(cov)
flattened = Flatten()(pl)


# fusion - combinig both
fused = tf.concat([averaged, flattened], axis=-1)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused)
p_price = Dense(len_price, activation='softmax', name='price')(fused)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)


# compile model with optimizer, loss values for each task, loss 
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)


model.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_69 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  input_68 (InputLayer)          [(None, 100)]        0           []
#
#  conv2d_21 (Conv2D)             (None, 49, 49, 32)   16416       ['input_69[0][0]']
#
#  embedding_28 (Embedding)       (None, 100, 100)     5000000     ['input_68[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 3, 3, 32)    0           ['conv2d_21[0][0]']
#  )
#
#  tf.math.reduce_mean_20 (TFOpLa  (None, 100)         0           ['embedding_28[0][0]']
#  mbda)
#
#  flatten_21 (Flatten)           (None, 288)          0           ['max_pooling2d_21[0][0]']
#
#  tf.concat_20 (TFOpLambda)      (None, 388)          0           ['tf.math.reduce_mean_20[0][0]',
#                                                                   'flatten_21[0][0]']
# ...

# %%
# Fitting the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': y_train_type,
        'price': y_train_price,
    },
    epochs=20,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_loss', patience=5, )
    ],
    verbose=1
)
# Out:
# Epoch 1/20
# 382/382 [==============================] - 27s 67ms/step - loss: 7.0040 - price_loss: 8.3862 - type_loss: 5.6218 - price_sparse_categorical_accuracy: 0.5161 - type_sparse_categorical_accuracy: 0.6661 - val_loss: 1.2427 - val_price_loss: 0.8631 - val_type_loss: 1.6223 - val_price_sparse_categorical_accuracy: 0.6258 - val_type_sparse_categorical_accuracy: 0.7647
# Epoch 2/20
# 382/382 [==============================] - 26s 68ms/step - loss: 1.0287 - price_loss: 0.8933 - type_loss: 1.1642 - price_sparse_categorical_accuracy: 0.6122 - type_sparse_categorical_accuracy: 0.7536 - val_loss: 0.9359 - val_price_loss: 0.8614 - val_type_loss: 1.0104 - val_price_sparse_categorical_accuracy: 0.6252 - val_type_sparse_categorical_accuracy: 0.7647
# Epoch 3/20
# ...

# %%
# we can do prediction on Testing set
y_predict = model.predict(
    {
        'summary': x_test_text_id,
        'image': x_test_image
    }
)


# probabilities
price_predicted = y_predict['price']
print(price_predicted)

# categories
price_category_predicted = np.argmax(price_predicted, axis=1)
print(price_category_predicted)
# Out:
# 230/230 [==============================] - 3s 12ms/step
# [[9.9205071e-01 7.9493467e-03 1.2395251e-08]
#  [9.1835135e-01 8.1648596e-02 2.1058621e-20]
#  [9.9999547e-01 4.5762931e-06 1.2987697e-10]
#  ...
#  [2.7483488e-03 9.9718082e-01 7.0812734e-05]
#  [9.9999881e-01 1.2113354e-06 4.3687223e-08]
#  [1.4780406e-04 9.9985218e-01 2.4584974e-19]]
# [0 0 0 ... 1 0 1]

# %%
# define function to save the csv file of the result after each trial

pd.DataFrame(
    {'id': test_data.id,
     'price': price_category_predicted}
).to_csv('Trial#1.csv', index=False)

# %%
# summarize history for Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ⚫ **OBSERVATION:**
#
# ▶  In **Trial #1** we notice that when we use **Multi-Modality** technique and the model with layers that discriped before to pridect the price the accuracy is **62.52%**

# %% [markdown]
# ## III.I.II) Trial #2 (Using Droupout Layer)

# %% [markdown]
# ⭐ In **Trial #2** we will use **Multi-modality** that use Two kinds of data(Text and Images) with **Multi-Task** to predict **both Price and Type** of the houses in our dataset.
#
# ⭐ In this Trial we will use simple **average of embedding** to train text data and will use simple **conv2D**, **Maxpool2D** and **flatten** Layers to train the images, after that we will concat the result of two models and then we add **Two Droupout layers** and then use **two Dense layers** with **Softmax** activation function **one for each Task**.
#
# ⭐ Then we will compile the model with **Adam** optimizer and using the **SparseCategoricalAccuracy** loss function and **SparseCategoricalAccuracy** metric to measure the performance of the model.

# %%
# Importing Libraries
from __future__ import absolute_import, division, print_function, unicode_literals
import collections
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
from tensorflow.keras.optimizers import Adam


# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding. 
embedded = keras.layers.Embedding(tokenizer.num_words, 100)(in_text)
averaged = tf.reduce_mean(embedded, axis=1)


# image part 
# simple conv2d.
cov = Conv2D(32, (16, 16))(in_image)
pl = MaxPool2D((16, 16))(cov)
flattened = Flatten()(pl)


# fusion - combinig both
fused = tf.concat([averaged, flattened], axis=-1)

# Adding Dropout Layer
fused1 = Dense(128, activation='relu')(fused)
dropout_1 = Dropout(rate = 0.2)(fused1)
fused1 = Dense(256, activation='relu')(dropout_1)


fused2 = Dense(256, activation='relu')(fused)
dropout_2 = Dropout(rate = 0.3)(fused2)
fused2 =  Dense(128, activation='relu')(dropout_2)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused1)
p_price = Dense(len_price, activation='softmax', name='price')(fused2)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)


# compile model with optimizer, loss values for each task, loss 
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)


model.summary()

# %%
# Fitting the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': y_train_type,
        'price': y_train_price,
    },
    epochs=20,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_sparse_categorical_accuracy', patience=5, )
    ],
    verbose=1
)

# %%
# we can do prediction on Testing set
y_predict = model.predict(
    {
        'summary': x_test_text_id,
        'image': x_test_image
    }
)


# probabilities
price_predicted = y_predict['price']
print(price_predicted)

# categories
price_category_predicted = np.argmax(price_predicted, axis=1)
print(price_category_predicted)
# Out:
# 230/230 [==============================] - 3s 11ms/step
# [[0.61123663 0.3264622  0.06230114]
#  [0.61123663 0.3264622  0.06230114]
#  [0.61123663 0.3264622  0.06230114]
#  ...
#  [0.61123663 0.3264622  0.06230114]
#  [0.61123663 0.3264622  0.06230114]
#  [0.61123663 0.3264622  0.06230114]]
# [0 0 0 ... 0 0 0]

# %%
# summarize history for Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# define function to save the csv file of the result after each trial

pd.DataFrame(
    {'id': test_data.id,
     'price': price_category_predicted}
).to_csv('Trial#2.csv', index=False)

# %% [markdown]
# ⚫ **OBSERVATION:**
#
# ▶  In **Trial #2** we notice that when we use **Multi-Modality** technique and the model with layers that discriped before to pridect the price the accuracy is **63.87%**

# %% [markdown]
# ## III.I.III) Trial #3 (Using GRU Layer)

# %% [markdown]
# ⭐ In **Trial #3** we will use **Multi-modality** that use Two kinds of data(Text and Images) with **Multi-Task** to predict **both Price and Type** of the houses in our dataset.
#
# ⭐ In this Trial we will use **Two GRU** layers that it is more effecient in terms of computation then use simple **average of embedding** to train text data and will use simple **conv2D**, **Maxpool2D** and **flatten** Layers to train the images, after that we will concat the result of two models and then use **two Dense layers** with **Softmax** activation function **one for each Task** maybe adding **GRU layers** give me a good accuracy since it's has two gates **(update gate and reset gate).**
#
# ⭐ Then we will compile the model with **Adam** optimizer and using the **SparseCategoricalAccuracy** loss function and **SparseCategoricalAccuracy** metric to measure the performance of the model.

# %%
# Importing Libraries
from __future__ import absolute_import, division, print_function, unicode_literals
import collections
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
from tensorflow.keras.optimizers import Adam

# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding 
embedded = keras.layers.Embedding(tokenizer.num_words, 100)(in_text)
# Adding Two GRU Layers
text_gru1 = tf.keras.layers.GRU(32,return_sequences=True)(embedded)
text_gru2 = tf.keras.layers.GRU(16,return_sequences=True)(text_gru1)
averaged = tf.reduce_mean(text_gru2, axis=1)


# image part 
# simple conv2d
cov = Conv2D(32, (16, 16))(in_image)
pl = MaxPool2D((16, 16))(cov)
flattened = Flatten()(pl)

# fusion - combinig both
fused = tf.concat([averaged, flattened], axis=-1)


# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused)
p_price = Dense(len_price, activation='softmax', name='price')(fused)



# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)


# compile model with optimizer, loss values for each task, loss 
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)


model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_42 (InputLayer)          [(None, 100)]        0           []
#
#  embedding_17 (Embedding)       (None, 100, 100)     5000000     ['input_42[0][0]']
#
#  input_43 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  gru_19 (GRU)                   (None, 100, 32)      12864       ['embedding_17[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 49, 49, 32)   16416       ['input_43[0][0]']
#
#  gru_20 (GRU)                   (None, 100, 16)      2400        ['gru_19[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 3, 3, 32)    0           ['conv2d_14[0][0]']
#  )
#
#  tf.math.reduce_mean_13 (TFOpLa  (None, 16)          0           ['gru_20[0][0]']
#  mbda)
#
#  flatten_14 (Flatten)           (None, 288)          0           ['max_pooling2d_14[0][0]']
#
# ...

# %%
# Fitting the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': y_train_type,
        'price': y_train_price,
    },
    epochs=20,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_sparse_categorical_accuracy', patience=5, )
    ],
    verbose=1
)
# Out:
# Epoch 1/20
# 382/382 [==============================] - 39s 94ms/step - loss: 26.0674 - price_loss: 23.0383 - type_loss: 29.0966 - price_sparse_categorical_accuracy: 0.5102 - type_sparse_categorical_accuracy: 0.5829 - val_loss: 8.8556 - val_price_loss: 8.4814 - val_type_loss: 9.2297 - val_price_sparse_categorical_accuracy: 0.3119 - val_type_sparse_categorical_accuracy: 0.5020
# Epoch 2/20
# 382/382 [==============================] - 35s 91ms/step - loss: 7.2235 - price_loss: 5.0810 - type_loss: 9.3660 - price_sparse_categorical_accuracy: 0.5399 - type_sparse_categorical_accuracy: 0.5976 - val_loss: 8.6955 - val_price_loss: 4.0807 - val_type_loss: 13.3103 - val_price_sparse_categorical_accuracy: 0.5203 - val_type_sparse_categorical_accuracy: 0.2215
# Epoch 3/20
# ...

# %%
# we can do prediction on Testing set
y_predict = model.predict(
    {
        'summary': x_test_text_id,
        'image': x_test_image
    }
)


# probabilities
price_predicted = y_predict['price']
print(price_predicted)

# categories
price_category_predicted = np.argmax(price_predicted, axis=1)
print(price_category_predicted)
# Out:
# 230/230 [==============================] - 4s 17ms/step
# [[9.9999309e-01 6.8899431e-06 1.3666926e-08]
#  [9.9999988e-01 1.7719638e-07 6.4734190e-11]
#  [4.6222060e-04 1.8099188e-04 9.9935681e-01]
#  ...
#  [1.0000000e+00 9.2086602e-11 2.3133778e-19]
#  [1.0000000e+00 3.9245118e-13 4.3496240e-14]
#  [7.4595039e-07 2.5300640e-05 9.9997389e-01]]
# [0 0 2 ... 0 0 2]

# %%
# summarize history for Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# define function to save the csv file of the result after each trial

pd.DataFrame(
    {'id': test_data.id,
     'price': price_category_predicted}
).to_csv('Trial#31.csv', index=False)

# %% [markdown]
# ⚫ **OBSERVATION:**
#
# ▶  In **Trial #3** we notice that when we use **Multi-Modality** technique with **GRU** layer and the model with layers that discriped before to pridect the price the accuracy is **60.55%**

# %% [markdown]
# ## III.I.IV) Trial #4 (Using LSTM layer)

# %% [markdown]
# ⭐ In **Trial #4** we will use **Multi-modality** that use Two kinds of data(Text and Images) with **Multi-Task** to predict **both Price and Type** of the houses in our dataset.
#
# ⭐ In this Trial we will use **Two LSTM** layers that it is effective in memorizing important information so it will perform fairly better, then use simple **average of embedding** to train text data and will use simple **conv2D**, **Maxpool2D** and **flatten** Layers to train the images, after that we will concat the result of two models and then use **two Dense layers** with **Softmax** activation function **one for each Task**.
#
#
# ⭐ Then we will compile the model with **Adam** optimizer and using the **SparseCategoricalAccuracy** loss function and **SparseCategoricalAccuracy** metric to measure the performance of the model.

# %%
# Importing Libraries
from __future__ import absolute_import, division, print_function, unicode_literals
import collections
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
from tensorflow.keras.optimizers import Adam

# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding.
embedded = keras.layers.Embedding(tokenizer.num_words, 100)(in_text)
# Adding LSTM layers
text_lstm1 = tf.keras.layers.LSTM(32,return_sequences=True)(embedded)
text_lstm2 = tf.keras.layers.LSTM(16,return_sequences=True)(text_lstm1)
averaged = tf.reduce_mean(text_lstm2, axis=1)


# image part 
# simple conv2d.
cov = Conv2D(32, (16, 16))(in_image)
pl = MaxPool2D((16, 16))(cov)
flattened = Flatten()(pl)

# fusion - combinig both
fused = tf.concat([averaged, flattened], axis=-1)


# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused)
p_price = Dense(len_price, activation='softmax', name='price')(fused)



# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)


# compile model with optimizer, loss values for each task, loss 
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)


model.summary()
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_70 (InputLayer)          [(None, 100)]        0           []
#
#  embedding_29 (Embedding)       (None, 100, 100)     5000000     ['input_70[0][0]']
#
#  input_71 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  lstm_15 (LSTM)                 (None, 100, 32)      17024       ['embedding_29[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 49, 49, 32)   16416       ['input_71[0][0]']
#
#  lstm_16 (LSTM)                 (None, 100, 16)      3136        ['lstm_15[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 3, 3, 32)    0           ['conv2d_22[0][0]']
#  )
#
#  tf.math.reduce_mean_21 (TFOpLa  (None, 16)          0           ['lstm_16[0][0]']
#  mbda)
#
#  flatten_22 (Flatten)           (None, 288)          0           ['max_pooling2d_22[0][0]']
#
# ...

# %%
# Fitting the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': y_train_type,
        'price': y_train_price,
    },
    epochs=20,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_sparse_categorical_accuracy', patience=5, )
    ],
    verbose=1
)
# Out:
# Epoch 1/20
# 367/367 [==============================] - 36s 89ms/step - loss: 29.1683 - price_loss: 24.9261 - type_loss: 33.4105 - price_sparse_categorical_accuracy: 0.4949 - type_sparse_categorical_accuracy: 0.5852 - val_loss: 14.2972 - val_price_loss: 11.8171 - val_type_loss: 16.7773 - val_price_sparse_categorical_accuracy: 0.6119 - val_type_sparse_categorical_accuracy: 0.7183
# Epoch 2/20
# 367/367 [==============================] - 33s 91ms/step - loss: 10.9616 - price_loss: 7.5977 - type_loss: 14.3255 - price_sparse_categorical_accuracy: 0.5220 - type_sparse_categorical_accuracy: 0.5991 - val_loss: 8.4738 - val_price_loss: 7.3938 - val_type_loss: 9.5537 - val_price_sparse_categorical_accuracy: 0.4134 - val_type_sparse_categorical_accuracy: 0.6774
# Epoch 3/20
# ...

# %%
# we can do prediction on training set
y_predict = model.predict(
    {
        'summary': x_test_text_id,
        'image': x_test_image
    }
)


# probabilities
price_predicted = y_predict['price']
print(price_predicted)

# categories
price_category_predicted = np.argmax(price_predicted, axis=1)
print(price_category_predicted)
# Out:
# 230/230 [==============================] - 5s 21ms/step
# [[2.84992874e-01 4.63967562e-01 2.51039475e-01]
#  [1.00000000e+00 6.37218722e-10 6.19027467e-14]
#  [9.99163270e-01 8.36769352e-04 3.89267722e-18]
#  ...
#  [9.99991775e-01 1.98144384e-15 8.19314937e-06]
#  [9.99997258e-01 2.76341189e-06 3.48768410e-08]
#  [1.06415566e-04 3.97202298e-02 9.60173309e-01]]
# [1 0 0 ... 0 0 2]

# %%
# summarize history for Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# define function to save the csv file of the result after each trial

pd.DataFrame(
    {'id': test_data.id,
     'price': price_category_predicted}
).to_csv('Trial#4.csv', index=False)

# %% [markdown]
# ⚫ **OBSERVATION:**
#
# ▶  In **Trial #4** we notice that when we use **Multi-Modality** technique with **LSTM** layers and the model with layers that discriped before to pridect the price the accuracy is **59.44%**
#
# 👉🏻The score a little bit lower than before, so I think that's because I added LSTM layer and make the image classifier layer more complex.

# %% [markdown]
# ## III.I.V) Trial #5 (Using BiDimentional Layer)

# %% [markdown]
# ⭐ In **Trial #5** we will use **Multi-modality** that use Two kinds of data(Text and Images) with **Multi-Task** to predict **both Price and Type** of the houses in our dataset.
#
# ⭐ In this Trial we will use **Two Bidirectional GRU** layers that it is more effecient in terms of computation to improve our model then use simple **average of embedding** to train text data and will use simple **conv2D**, **Maxpool2D** and **flatten** Layers to train the images, after that we will concat the result of two models and then we add **Two Droupout layers** and then we use **two Dense layers** with **Softmax** activation function **one for each Task** maybe adding **Bidirectional GRU layers** give me a good accuracy since it works in two dimentions **backward (from the future to the past)** and **forward (from the past to the future).**
#
# ⭐ Then we will compile the model with **Adam** optimizer and using the **SparseCategoricalAccuracy** loss function and **SparseCategoricalAccuracy** metric to measure the performance of the model.

# %%
# Importing Libraries
from __future__ import absolute_import, division, print_function, unicode_literals
import collections
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
from tensorflow.keras.optimizers import Adam

# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding. 
embedded = keras.layers.Embedding(tokenizer.num_words, 100)(in_text)
# Adding Bidirectional GRU Layers
text_gru1 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32,return_sequences=True))(embedded)
text_gru2 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(16,return_sequences=True))(text_gru1)
averaged = tf.reduce_mean(text_gru2, axis=1)


# image part 
# simple conv2d.
cov = Conv2D(32, (16, 16))(in_image)
pl = MaxPool2D((16, 16))(cov)
flattened = Flatten()(pl)

# fusion - combinig both
fused = tf.concat([averaged, flattened], axis=-1)


# Adding Droupout layers
fused1 = Dense(128, activation='relu')(fused)
dropout_1 = Dropout(rate = 0.2)(fused1)
fused1 = Dense(256, activation='relu')(dropout_1)


fused2 = Dense(256, activation='relu')(fused)
dropout_2 = Dropout(rate = 0.3)(fused2)
fused2 =  Dense(128, activation='relu')(dropout_2)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused1)
p_price = Dense(len_price, activation='softmax', name='price')(fused2)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)


# compile model with optimizer, loss values for each task, loss 
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)


model.summary()
# Out:
# Model: "model_16"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_74 (InputLayer)          [(None, 100)]        0           []
#
#  embedding_31 (Embedding)       (None, 100, 100)     5000000     ['input_74[0][0]']
#
#  input_75 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  bidirectional_15 (Bidirectiona  (None, 100, 64)     25728       ['embedding_31[0][0]']
#  l)
#
#  conv2d_24 (Conv2D)             (None, 49, 49, 32)   16416       ['input_75[0][0]']
#
#  bidirectional_16 (Bidirectiona  (None, 100, 32)     7872        ['bidirectional_15[0][0]']
#  l)
#
#  max_pooling2d_24 (MaxPooling2D  (None, 3, 3, 32)    0           ['conv2d_24[0][0]']
#  )
#
#  tf.math.reduce_mean_23 (TFOpLa  (None, 32)          0           ['bidirectional_16[0][0]']
#  mbda)
#
# ...

# %%
# Fitting the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': y_train_type,
        'price': y_train_price,
    },
    epochs=20,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_sparse_categorical_accuracy', patience=5, )
    ],
    verbose=1
)
# Out:
# Epoch 1/20
# 367/367 [==============================] - 42s 101ms/step - loss: 7.9175 - price_loss: 9.3294 - type_loss: 6.5057 - price_sparse_categorical_accuracy: 0.5104 - type_sparse_categorical_accuracy: 0.6625 - val_loss: 1.0522 - val_price_loss: 0.9329 - val_type_loss: 1.1714 - val_price_sparse_categorical_accuracy: 0.5130 - val_type_sparse_categorical_accuracy: 0.7688
# Epoch 2/20
# 367/367 [==============================] - 35s 96ms/step - loss: 1.0628 - price_loss: 0.8729 - type_loss: 1.2528 - price_sparse_categorical_accuracy: 0.6116 - type_sparse_categorical_accuracy: 0.7541 - val_loss: 0.9335 - val_price_loss: 0.8417 - val_type_loss: 1.0254 - val_price_sparse_categorical_accuracy: 0.6241 - val_type_sparse_categorical_accuracy: 0.7688
# Epoch 3/20
# ...

# %%
# we can do prediction on training set
y_predict = model.predict(
    {
        'summary': x_test_text_id,
        'image': x_test_image
    }
)


# probabilities
price_predicted = y_predict['price']
print(price_predicted)

# categories
price_category_predicted = np.argmax(price_predicted, axis=1)
print(price_category_predicted)
# Out:
# 230/230 [==============================] - 5s 20ms/step
# [[0.6293591  0.3086898  0.06195104]
#  [0.6293591  0.3086898  0.06195104]
#  [0.6293591  0.3086898  0.06195104]
#  ...
#  [0.6293591  0.3086898  0.06195104]
#  [0.6293591  0.30868983 0.06195105]
#  [0.6293591  0.30868983 0.06195105]]
# [0 0 0 ... 0 0 0]

# %%
# summarize history for Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# define function to save the csv file of the result after each trial

pd.DataFrame(
    {'id': test_data.id,
     'price': price_category_predicted}
).to_csv('Trial#5.csv', index=False)

# %% [markdown]
# ⚫ **OBSERVATION:**
#
# ▶  In **Trial #5** we notice that when we use **Multi-Modality** technique with **Bidirectional GRU** layers and the model with layers that discriped before to pridect the price the accuracy is **62.41%**
#
# 👉🏻The score is a little bit better, so I think that's help the model.

# %% [markdown]
# ## III.II.VI) Trial #6 (Using Bidimentional LSTM layer)

# %% [markdown]
# ⭐ In **Trial #6** we will use **Multi-modality** that use Two kinds of data(Text and Images) with **Multi-Task** to predict **both Price and Type** of the houses in our dataset.
#
# ⭐ In this Trial we will use **Two Bidirectional LSTM** layers that it is effective in memorizing important information. Then use simple **average of embedding** to train text data and will use simple **conv2D**, **Maxpool2D** and **flatten** Layers to train the images, after that we will concat the result of two models and then we add **Two Droupout layers** and then we use **two Dense layers** with **Softmax** activation function **one for each Task** maybe adding **Bidirectional LSTM** will memorize the sequence **Backward** (from the future to the past) and **Forward** (from the past to the future).
#
# ⭐ Then we will compile the model with **Adam** optimizer and using the **SparseCategoricalAccuracy** loss function and **SparseCategoricalAccuracy** metric to measure the performance of the model.

# %%
# Importing Libraries
from __future__ import absolute_import, division, print_function, unicode_literals
import collections
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
from tensorflow.keras.optimizers import Adam

# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding. you can change it to anything else as needed
embedded = keras.layers.Embedding(tokenizer.num_words, 100)(in_text)
tex_lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32,return_sequences=True))(embedded)
tex_lstm2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16,return_sequences=True))(tex_lstm1)
averaged = tf.reduce_mean(tex_lstm2, axis=1)


# image part 
# simple conv2d. you can change it to anything else as needed
cov = Conv2D(32, (16, 16))(in_image)
pl = MaxPool2D((16, 16))(cov)
flattened = Flatten()(pl)

# fusion - combinig both
fused = tf.concat([averaged, flattened], axis=-1)

fused1 = Dense(128, activation='relu')(fused)
dropout_1 = Dropout(rate = 0.2)(fused1)
fused1 = Dense(256, activation='relu')(dropout_1)


fused2 = Dense(256, activation='relu')(fused)
dropout_2 = Dropout(rate = 0.3)(fused2)
fused2 =  Dense(128, activation='relu')(dropout_2)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused1)
p_price = Dense(len_price, activation='softmax', name='price')(fused2)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)


# compile model with optimizer, loss values for each task, loss 
# weights for each task.
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)


model.summary()
# Out:
# Model: "model_21"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_80 (InputLayer)          [(None, 100)]        0           []
#
#  embedding_33 (Embedding)       (None, 100, 100)     5000000     ['input_80[0][0]']
#
#  input_81 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  bidirectional_19 (Bidirectiona  (None, 100, 64)     34048       ['embedding_33[0][0]']
#  l)
#
#  conv2d_28 (Conv2D)             (None, 49, 49, 32)   16416       ['input_81[0][0]']
#
#  bidirectional_20 (Bidirectiona  (None, 100, 32)     10368       ['bidirectional_19[0][0]']
#  l)
#
#  max_pooling2d_28 (MaxPooling2D  (None, 3, 3, 32)    0           ['conv2d_28[0][0]']
#  )
#
#  tf.math.reduce_mean_25 (TFOpLa  (None, 32)          0           ['bidirectional_20[0][0]']
#  mbda)
#
# ...

# %%
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': y_train_type,
        'price': y_train_price,
    },
    epochs=20,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_sparse_categorical_accuracy', patience=15, )
    ],
    verbose=1
)
# Out:
# Epoch 1/20
# 367/367 [==============================] - 35s 96ms/step - loss: 0.9248 - price_loss: 0.8381 - type_loss: 1.0115 - price_sparse_categorical_accuracy: 0.6196 - type_sparse_categorical_accuracy: 0.7560 - val_loss: 0.8998 - val_price_loss: 0.8296 - val_type_loss: 0.9700 - val_price_sparse_categorical_accuracy: 0.6241 - val_type_sparse_categorical_accuracy: 0.7688
# Epoch 2/20
# 367/367 [==============================] - 35s 95ms/step - loss: 0.9243 - price_loss: 0.8374 - type_loss: 1.0112 - price_sparse_categorical_accuracy: 0.6196 - type_sparse_categorical_accuracy: 0.7560 - val_loss: 0.9002 - val_price_loss: 0.8296 - val_type_loss: 0.9708 - val_price_sparse_categorical_accuracy: 0.6241 - val_type_sparse_categorical_accuracy: 0.7688
# Epoch 3/20
# ...

# %%
# we can do prediction on training set
y_predict = model.predict(
    {
        'summary': x_test_text_id,
        'image': x_test_image
    }
)


# probabilities
price_predicted = y_predict['price']
print(price_predicted)

# categories
price_category_predicted = np.argmax(price_predicted, axis=1)
print(price_category_predicted)


# probabilities
type_predicted = y_predict['type']
print(type_predicted)

# categories
type_category_predicted = np.argmax(type_predicted, axis=1)
print(type_category_predicted)
# Out:
# 230/230 [==============================] - 5s 23ms/step
# [[0.6106476  0.33772254 0.05162985]
#  [0.6106476  0.33772254 0.05162985]
#  [0.6106476  0.33772254 0.05162985]
#  ...
#  [0.6106476  0.33772254 0.05162985]
#  [0.6106476  0.33772254 0.05162985]
#  [0.6106476  0.33772254 0.05162985]]
# [0 0 0 ... 0 0 0]

# %%
# summarize history for Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# define function to save the csv file of the result after each trial

pd.DataFrame(
    {'id': test_data.id,
     'price': price_category_predicted,
    'type': type_category_predicted}
).to_csv('Trial#6.csv', index=False)

# %% [markdown]
# ⚫ **OBSERVATION:**
#
# ▶  In **Trial #6** we notice that when we use **Multi-Modality** technique with **Bidirectional LSTM** layers and the model with layers that discriped before to pridect the price the accuracy is **62.41%.**
#
# 👉🏻The score is the same with using **Bidirectional GRU** which is good.

# %% [markdown]
# ## III.II) Single-Modality Multi-Task

# %% [markdown]
# #### ▶ Using Single-Modailty Teqniques with one of two kind of data that we have (text and Images) so we in this Section we will use only one kind of data  (Text only)

# %% [markdown]
# ## III.II.I) Trial #7 (Predicting both Price and Type based on Text only)

# %% [markdown]
# ⭐ In **Trial #7** we will use **Single-modality** that we use only one kind of data (Text or Image) with **Multi-Task** to predict **both Price and Type** of the houses in our dataset.
#
# ⭐ In this Trial we will use **Two Bidirectional LSTM** layers that it is effective in memorizing important information. Then use simple **average of embedding** to train text data then we add **Droupout layer** and then we use **two Dense layers** with **Softmax** activation function **one for each Task** maybe adding **Bidirectional LSTM** will memorize the sequence **Backward** (from the future to the past) and **Forward** (from the past to the future).
#
# ⭐ Then we will compile the model with **Adam** optimizer and using the **SparseCategoricalAccuracy** loss function and **SparseCategoricalAccuracy** metric to measure the performance of the model.

# %%
# Importing libraries
from __future__ import absolute_import, division, print_function, unicode_literals
import collections
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
from tensorflow.keras.optimizers import Adam


# The text input.
in_text = keras.Input(batch_shape=(None, max_len))

# simple average of embedding.
embedded = keras.layers.Embedding(tokenizer.num_words, 100)(in_text)

# Using Bidirectional LSTM layer
text_lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32,return_sequences=True))(embedded)
text_lstm2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16,return_sequences=True))(text_lstm1)
averaged = tf.reduce_mean(text_lstm2, axis=1)

# Using Dropout layer
fused1 = Dense(128, activation='relu')(averaged)
dropout_1 = Dropout(rate = 0.2)(fused1)
fused1 = Dense(256, activation='relu')(dropout_1)


# Multi-task learning (each a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused1)
p_price = Dense(len_price, activation='softmax', name='price')(fused1)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)


# compile model with optimizer, loss values for each task, loss 
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)


model.summary()
# Out:
# Model: "model_17"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_76 (InputLayer)          [(None, 100)]        0           []
#
#  embedding_32 (Embedding)       (None, 100, 100)     5000000     ['input_76[0][0]']
#
#  bidirectional_17 (Bidirectiona  (None, 100, 64)     34048       ['embedding_32[0][0]']
#  l)
#
#  bidirectional_18 (Bidirectiona  (None, 100, 32)     10368       ['bidirectional_17[0][0]']
#  l)
#
#  tf.math.reduce_mean_24 (TFOpLa  (None, 32)          0           ['bidirectional_18[0][0]']
#  mbda)
#
#  dense_32 (Dense)               (None, 128)          4224        ['tf.math.reduce_mean_24[0][0]']
#
#  dropout_12 (Dropout)           (None, 128)          0           ['dense_32[0][0]']
#
#  dense_33 (Dense)               (None, 256)          33024       ['dropout_12[0][0]']
#
# ...

# %%
# Fitting the model
history = model.fit(
    x={
        'summary': x_train_text_id
    },
    y={
        'type': y_train_type,
        'price': y_train_price,
    },
    epochs=20,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_sparse_categorical_accuracy', patience=5, )
    ],
    verbose=1
)
# Out:
# Epoch 1/20
# 367/367 [==============================] - 31s 71ms/step - loss: 0.9608 - price_loss: 0.8432 - type_loss: 1.0783 - price_sparse_categorical_accuracy: 0.6162 - type_sparse_categorical_accuracy: 0.7538 - val_loss: 0.8570 - val_price_loss: 0.8013 - val_type_loss: 0.9127 - val_price_sparse_categorical_accuracy: 0.6276 - val_type_sparse_categorical_accuracy: 0.7688
# Epoch 2/20
# 367/367 [==============================] - 25s 69ms/step - loss: 0.8370 - price_loss: 0.7983 - type_loss: 0.8756 - price_sparse_categorical_accuracy: 0.6311 - type_sparse_categorical_accuracy: 0.7541 - val_loss: 0.8317 - val_price_loss: 0.7905 - val_type_loss: 0.8730 - val_price_sparse_categorical_accuracy: 0.6317 - val_type_sparse_categorical_accuracy: 0.7688
# Epoch 3/20
# ...

# %%
# we can do prediction on training set
y_predict = model.predict(
    {
        'summary': x_test_text_id
    }
)

# probabilities
price_predicted = y_predict['price']
print(price_predicted)

# categories
price_category_predicted = np.argmax(price_predicted, axis=1)
print(price_category_predicted)

# probabilities
type_predicted = y_predict['type']
print(type_predicted)

# categories
type_category_predicted = np.argmax(type_predicted, axis=1)
print(type_category_predicted)
# Out:
# 230/230 [==============================] - 3s 13ms/step
# [[1.1827235e-01 8.7179422e-01 9.9334307e-03]
#  [9.9661320e-01 3.3590321e-03 2.7752651e-05]
#  [9.9906522e-01 9.3416870e-04 5.4892774e-07]
#  ...
#  [8.6882681e-01 1.1384424e-01 1.7328987e-02]
#  [9.9962342e-01 3.7606779e-04 4.2556081e-07]
#  [7.9569930e-01 1.7084329e-01 3.3457439e-02]]
# [1 0 0 ... 0 0 0]
# [[1.4089715e-11 4.4789973e-05 1.2374122e-07 ... 1.7255956e-09
#   1.6610078e-03 5.3828323e-08]
#  [3.7405783e-08 7.3232777e-02 2.7035077e-03 ... 8.6104730e-05
#   8.7107763e-02 9.2933793e-04]
#  [3.2259338e-12 1.5901543e-03 5.4408949e-05 ... 3.3688758e-07
#   2.7942820e-02 2.2062530e-05]
#  ...
#  [1.7059765e-04 1.6368872e-01 2.7996095e-02 ... 6.5329629e-03
#   1.2336056e-01 1.3888359e-02]
#  [2.8141618e-11 9.1538414e-02 8.4175044e-05 ... 7.2325128e-07
#   2.0549560e-02 2.8293371e-05]
#  [8.7792338e-05 5.5612105e-01 6.0933544e-03 ... 1.4369979e-03
#   2.2802334e-02 2.4548362e-03]]
# [18 17 17 ... 17 17  1]

# %%
# summarize history for Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# define function to save the csv file of the result after each trial

pd.DataFrame(
    {'id': test_data.id,
     'price': price_category_predicted,
    'type': type_category_predicted}
).to_csv('Trial#7.csv', index=False)

# %% [markdown]
# ⚫ **OBSERVATION:**
#
# ▶  In **Trial #8** we notice that when we use **Single-Modality** technique with **Bidirectional LSTM** layers and the model with layers that discriped before to pridect the price the accuracy is **63.31%.**
#
# 👉🏻The score is a little better than using **Multi-Modality** Because this model is specific to produce a specific output, so it has been well trained on this task.

# %% [markdown]
# # ***Part IV) Answering the Questions*** 😃

# %% [markdown]
# ## 🌈 **Q1:**  Is fully-connected model a good one for sequential data? Why? How about for image data? Is it good? Why?
#
#
# ⭐ A fully-connected model may not be a good choice for sequential data because it does not take into account the sequential nature of the data. Fully-connected models are also known as feedforward neural networks and are typically used for non-sequential data such as tabular data. Sequential data, on the other hand, has a temporal dimension, and the order of the data points matters.
#
# ⭐ For sequential data, recurrent neural networks (RNNs) such as the GRU and LSTM are more suitable. RNNs are designed to handle sequential data by maintaining a "memory" of the previous inputs, which allows them to capture temporal dependencies and patterns. The GRU and LSTM are both types of RNNs that are commonly used for natural language processing (NLP) tasks such as text classification and language translation.
#
# ⭐ For image data, fully-connected models may not be the best choice either. Image data is high-dimensional and has a spatial structure that is not captured by fully-connected layers. Instead, convolutional neural networks (CNNs) are typically used for image data. CNNs are designed to handle the spatial structure of image data by using convolutional layers that can learn spatial features such as edges and textures.
#
# 🔥 In summary, fully-connected models are not typically used for sequential or image data. Instead, RNNs such as the GRU and LSTM are used for sequential data, while CNNs are used for image data. These specialized types of models are designed to capture the unique characteristics of each type of data and achieve better performance than fully-connected models.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## 🌈 **Q2:** What is gradient vanishing and gradient explosion, and how GRU/LSTM tries to mitigate this problem?
#
#
# 👉🏻 Gradient vanishing and gradient explosion are two common problems that can occur during the training of neural networks, including recurrent neural networks (RNNs) such as the GRU and LSTM.
#
# ☘️ Gradient vanishing occurs when the gradients become very small as they propagate through the layers of the network during backpropagation, which can cause the weights to update very slowly or not at all. This can lead to slow convergence or even convergence to a suboptimal solution.
#
# ☘️ Gradient explosion, on the other hand, occurs when the gradients become very large, which can cause the weights to update too quickly and lead to overfitting or divergence.
#
# 👉🏻 The GRU and LSTM were designed to mitigate these problems by using a mechanism called gated recurrent units (GRUs) or long short-term memory (LSTM) cells, respectively. These mechanisms use gates to control the flow of information through the network and allow it to selectively remember or forget information from previous time steps.
#
# ⭐ In the GRU, there are two gates: a reset gate and an update gate. The reset gate controls how much of the previous hidden state is used to compute the current hidden state, while the update gate controls how much of the new input is used to update the current hidden state.
#
# ⭐ In the LSTM, there are three gates: an input gate, a forget gate, and an output gate. The input gate controls how much of the new input is used to update the memory cell, while the forget gate controls how much of the previous memory cell is forgotten. The output gate controls how much of the memory cell is used to compute the current hidden state.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## 🌈 **Q3:** What is multi-objective/multi-task learning? What is multi-modality learning? How do you use them in this assignment?
#
#
# ⭐ Multi-objective/multi-task learning refers to the process of training a single model to perform multiple tasks or predict multiple target variables simultaneously. This is often done by sharing some of the lower layers of the model across tasks, while maintaining separate output layers for each task. The idea is that the shared layers can capture common features across tasks, while the separate output layers can capture task-specific features.
#
# ⭐ Multi-modality learning refers to the process of training a single model to handle multiple modalities of data, such as text and image data. This is often done by combining the features learned from each modality before making a prediction.
#
# 🔥 I used in this Assignment both text and Image **(Multi-Modality)** to predict both price and type **(Multi-task)** that each is a **(Multi-class)** with different techniques and different layers in each moddel. So, I used **(Multi-Modality)** by combining the features learned from both textual and image data before making a prediction about both the price and type of the listing.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## 🌈 **Q4:** What is the difference among xgboost, lightgbm and catboost
#
#
#
# 👉🏻 XGBoost, LightGBM, and CatBoost are all popular open-source gradient boosting frameworks used for machine learning tasks. While they share some similarities, there are some differences between them:
#
# ☘️ Training speed: LightGBM and CatBoost are generally faster than XGBoost due to their optimized algorithms for handling large datasets. LightGBM uses a histogram-based algorithm for splitting and binning data, while CatBoost uses a combination of ordered boosting and random permutations. XGBoost uses a pre-sorted algorithm for splitting data.
#
# ☘️ Regularization techniques: All three frameworks support various regularization techniques such as L1 and L2 regularization, but CatBoost also supports a novel technique called "ordered boosting" that can handle non-random patterns in the data.
#
# ☘️ Categorical feature handling: CatBoost is designed to handle categorical features more efficiently than XGBoost and LightGBM. It uses an ordered boosting algorithm that can handle categorical features with a large number of categories and missing values without requiring feature engineering.
#
# 🔥 In summary, while XGBoost, LightGBM, and CatBoost share some similarities such as their use of gradient boosting algorithms, they differ in terms of training speed, memory efficiency, categorical feature handling, regularization techniques, and programming language compatibility. The choice of framework depends on the specific needs of the project and the characteristics of the data.
